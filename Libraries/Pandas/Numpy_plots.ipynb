# %%
import numpy as np
x=np.linspace(-20,20,100)

# %%
x.size
# Out:
# 100

# %%
y=np.sin(x)

# %%
y.size
# Out:
# 100

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
y=x*x+2*x+6

# %%
plt.plot(x,y)
