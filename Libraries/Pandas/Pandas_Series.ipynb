# %%
import  numpy as np
import pandas as pd
#Importing data using read_csv()
df=pd.read_csv("matches.csv")

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
type(df['winner'].value_counts())
# Out:
# pandas.core.series.Series

# %%
ser=df['winner'].value_counts()

# %%
ser.head()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: count, dtype: int64

# %%
ser.tail()
# Out:
# winner
# Gujarat Lions              13
# Pune Warriors              12
# Rising Pune Supergiant     10
# Kochi Tuskers Kerala        6
# Rising Pune Supergiants     5
# Name: count, dtype: int64

# %%
ser['Kochi Tuskers Kerala']
# Out:
# np.int64(6)

# %%
ser.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5])

# %%
ser.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object', name='winner')

# %%
df['team1'].value_counts()+df['team2'].value_counts()    #Supports other logical and arithmetic operations  IF indexes of two series are same .....
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %%
(df['team1'].value_counts()+df['team2'].value_counts() ).sort_values()  #By default ascending sorting
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Rising Pune Supergiant          16
# Gujarat Lions                   30
# Pune Warriors                   46
# Deccan Chargers                 75
# Sunrisers Hyderabad             76
# Rajasthan Royals               118
# Chennai Super Kings            131
# Delhi Daredevils               147
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Royal Challengers Bangalore    152
# Mumbai Indians                 157
# Name: count, dtype: int64

# %%
(df['team1'].value_counts()+df['team2'].value_counts() ).sort_values(ascending=False, )   #Descending
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
type(df['team1'].value_counts()+df['team2'].value_counts() )
# Out:
# pandas.core.series.Series

# %%
df.sort_values('date',ascending=False,inplace=True)

# %%
df
# Out:
#     id  season        city        date                        team1  \
# 58  59    2017   Hyderabad  2017-05-21               Mumbai Indians
# 57  58    2017   Bangalore  2017-05-19        Kolkata Knight Riders
# 56  57    2017   Bangalore  2017-05-17          Sunrisers Hyderabad
# 55  56    2017      Mumbai  2017-05-16       Rising Pune Supergiant
# 54  55    2017       Delhi  2017-05-14  Royal Challengers Bangalore
# ..  ..     ...         ...         ...                          ...
# 62  63    2008      Mumbai  2008-04-20               Mumbai Indians
# 63  64    2008     Kolkata  2008-04-20              Deccan Chargers
# 61  62    2008       Delhi  2008-04-19             Rajasthan Royals
# 60  61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 59  60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
#
#                           team2                  toss_winner toss_decision  \
# ...

# %%
df.sort_values(['city','date'])
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
df.sort_values(['city','date'],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# ..   ...     ...        ...         ...                          ...
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...
